# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv('amazon.csv')
Odata = pd.read_csv('retail_demand_dataset.csv')

# %%
Odata
# Out:
#              date  store_id product_id  category  price  discount  units_sold  \
# 0      2023-01-01         1       P001      Home  112.0         0          15
# 1      2023-01-02         1       P001      Home  106.4         5          18
# 2      2023-01-03         1       P001      Home  112.0         0           9
# 3      2023-01-04         1       P001      Home   89.6        20          25
# 4      2023-01-05         1       P001      Home   95.2        15          21
# ...           ...       ...        ...       ...    ...       ...         ...
# 54745  2023-12-27        10       P015  Clothing  442.0         0          17
# 54746  2023-12-28        10       P015  Clothing  442.0         0          14
# 54747  2023-12-29        10       P015  Clothing  419.9         5          15
# 54748  2023-12-30        10       P015  Clothing  442.0         0          21
# 54749  2023-12-31        10       P015  Clothing  442.0         0          15
#
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# ...

# %%
Odata.info
# Out:
# <bound method DataFrame.info of              date  store_id product_id  category  price  discount  units_sold  \
# 0      2023-01-01         1       P001      Home  112.0         0          15
# 1      2023-01-02         1       P001      Home  106.4         5          18
# 2      2023-01-03         1       P001      Home  112.0         0           9
# 3      2023-01-04         1       P001      Home   89.6        20          25
# 4      2023-01-05         1       P001      Home   95.2        15          21
# ...           ...       ...        ...       ...    ...       ...         ...
# 54745  2023-12-27        10       P015  Clothing  442.0         0          17
# 54746  2023-12-28        10       P015  Clothing  442.0         0          14
# 54747  2023-12-29        10       P015  Clothing  419.9         5          15
# 54748  2023-12-30        10       P015  Clothing  442.0         0          21
# 54749  2023-12-31        10       P015  Clothing  442.0         0          15
#
# ...

# %%
Odata.shape
# Out:
# (54750, 12)

# %%
Odata.describe()
# Out:
#            store_id        price      discount    units_sold  inventory_level  \
# count  54750.000000  54750.00000  54750.000000  54750.000000     54750.000000
# mean       5.500000    255.97775      5.024475     19.365553        78.736511
# std        2.872308    135.82799      6.125334      5.954674        35.996147
# min        1.000000     10.40000      0.000000      0.000000        20.000000
# 25%        3.000000    140.60000      0.000000     15.000000        48.000000
# 50%        5.500000    263.15000      5.000000     19.000000        77.000000
# 75%        8.000000    370.50000     10.000000     23.000000       106.000000
# max       10.000000    499.00000     20.000000     46.000000       186.000000
#
#             holiday     promotion   temperature    fuel_price
# count  54750.000000  54750.000000  54750.000000  54750.000000
# mean       0.287671      0.297790     25.011704     94.999164
# std        0.452681      0.457291      5.024495      2.001758
# ...

# %%
Odata.isnull().sum()
# Out:
# date               0
# store_id           0
# product_id         0
# category           0
# price              0
# discount           0
# units_sold         0
# inventory_level    0
# holiday            0
# promotion          0
# temperature        0
# fuel_price         0
# dtype: int64

# %%
Odata['date']= pd.to_datetime(Odata['date'])

# %%
Odata['Year']= Odata['date'].dt.year
Odata['Month']= Odata['date'].dt.month
Odata['Day']= Odata['date'].dt.day
Odata['Weekday']= Odata['date'].dt.weekday

# %%
Odata["lag_1"] = Odata["units_sold"].shift(1)
Odata["lag_7"] = Odata["units_sold"].shift(7)
Odata["lag_14"] = Odata["units_sold"].shift(14)

# %%
Odata2= Odata.copy()

# %%
Odata2.head()
# Out:
#         date  store_id product_id category  price  discount  units_sold  \
# 0 2023-01-01         1       P001     Home  112.0         0          15
# 1 2023-01-02         1       P001     Home  106.4         5          18
# 2 2023-01-03         1       P001     Home  112.0         0           9
# 3 2023-01-04         1       P001     Home   89.6        20          25
# 4 2023-01-05         1       P001     Home   95.2        15          21
#
#    inventory_level  holiday  promotion  temperature  fuel_price  Year  Month  \
# 0              157        1          1        19.01       99.28  2023      1
# 1              139        0          0        22.94       95.47  2023      1
# 2              130        0          0        12.80       96.21  2023      1
# 3              105        0          0        32.43       95.83  2023      1
# 4               84        0          0        24.30       94.93  2023      1
#
#    Day  Weekday  lag_1  lag_7  lag_14
# ...

# %%
Odata2.dropna()
# Out:
#             date  store_id product_id  category  price  discount  units_sold  \
# 14    2023-01-15         1       P001      Home  112.0         0          17
# 15    2023-01-16         1       P001      Home  112.0         0          12
# 16    2023-01-17         1       P001      Home  112.0         0          17
# 17    2023-01-18         1       P001      Home  112.0         0          10
# 18    2023-01-19         1       P001      Home   89.6        20          24
# ...          ...       ...        ...       ...    ...       ...         ...
# 54745 2023-12-27        10       P015  Clothing  442.0         0          17
# 54746 2023-12-28        10       P015  Clothing  442.0         0          14
# 54747 2023-12-29        10       P015  Clothing  419.9         5          15
# 54748 2023-12-30        10       P015  Clothing  442.0         0          21
# 54749 2023-12-31        10       P015  Clothing  442.0         0          15
#
# ...

# %%
features = [
    "price",
    "discount",
    "inventory_level",
    "promotion",
    "holiday",
    "Month",
    "Weekday",
    "lag_1",
    "lag_7",
    "lag_14"
]

# %%
target = "units_sold"

# %%
from sklearn.model_selection import train_test_split

# %%
x= Odata[features]
y= Odata[target]

x_train,x_test, y_train, y_test = train_test_split(
    x,y,test_size = 0.2, random_state= 42
)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (43800, 10)
# (10950, 10)
# (43800,)
# (10950,)

# %%
x_test.columns
# Out:
# Index(['price', 'discount', 'inventory_level', 'promotion', 'holiday', 'Month',
#        'Weekday', 'lag_1', 'lag_7', 'lag_14'],
#       dtype='object')

# %%
x_train.columns
# Out:
# Index(['price', 'discount', 'inventory_level', 'promotion', 'holiday', 'Month',
#        'Weekday', 'lag_1', 'lag_7', 'lag_14'],
#       dtype='object')

# %%
x_train.head()
# Out:
#         price  discount  inventory_level  promotion  holiday  Month  Weekday  \
# 23522  268.00         0               37          0        0      6        0
# 47823  470.25         5               33          0        0      1        0
# 44038   76.95         5              127          1        1      8        6
# 39268  267.00         0               26          0        0      8        2
# 7237   337.50        10               32          1        0     10        0
#
#        lag_1  lag_7  lag_14
# 23522   25.0   11.0    15.0
# 47823   13.0   17.0    13.0
# 44038   18.0   14.0    25.0
# 39268   19.0   33.0    12.0
# 7237    14.0   27.0    14.0

# %%
x_test.head()
# Out:
#        price  discount  inventory_level  promotion  holiday  Month  Weekday  \
# 6246   382.0         0               41          1        1      2        5
# 32248   41.8         5              125          0        0      5        1
# 49338  317.0         0               32          0        1      3        6
# 35720  366.7         5              107          0        1     11        6
# 28751   62.0         0               21          0        0     10        0
#
#        lag_1  lag_7  lag_14
# 6246    19.0    8.0    15.0
# 32248   13.0   21.0    19.0
# 49338   16.0   21.0    36.0
# 35720   22.0   23.0    16.0
# 28751   19.0   26.0    21.0

# %%
print(len(x_test)/len(Odata))
print(len(x_train)/len(Odata))
# Out:
# 0.2
# 0.8

# %%
Odata.columns
# Out:
# Index(['date', 'store_id', 'product_id', 'category', 'price', 'discount',
#        'units_sold', 'inventory_level', 'holiday', 'promotion', 'temperature',
#        'fuel_price', 'Year', 'Month', 'Day', 'Weekday', 'lag_1', 'lag_7',
#        'lag_14'],
#       dtype='object')

# %%
print(x_test.shape,x_train.shape)
# Out:
# (10950, 10) (43800, 10)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()

model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
predictions = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(y_test,predictions)
rmse = np.sqrt(mean_squared_error(y_test,predictions))

print("MAE:", mae)
print('RMSE:', rmse)
# Out:
# MAE: 3.6103954337899546
# RMSE: 4.512051874560116

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12,6))

plt.plot(y_test.values[:100], label= 'Actual')
plt.plot(predictions[:100], label = "Predicted")

plt.legend()
plt.title('Demand Forecasting')
plt.show()
